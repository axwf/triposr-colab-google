# %%
# %cd /content

# !git clone -b dev https://github.com/camenduru/TripoSR-hf
# %cd /content/TripoSR-hf

# !pip install -q trimesh omegaconf einops rembg gradio

# !pip install torchmcubes

# !pip install -q https://github.com/camenduru/wheels/releases/download/colab/torchmcubes-0.1.0-cp310-cp310-linux_x86_64.whl

# !uname -m

# !git clone https://github.com/torchmcubes/torchmcubes.git
# %cd torchmcubes

# !pip install -r requirements.txt
# !python setup.py install

# !rm -rf /content/TripoSR-hf

# %cd /content
# !git clone -b dev https://github.com/camenduru/TripoSR-hf
# %cd /content/TripoSR-hf

# Install compatible versions of all libraries to resolve conflicts
# !pip install huggingface-hub==0.26.0  # Compatible with most libraries
# !pip install transformers==4.41.0     # Compatible with sentence-transformers
# !pip install peft==0.14.0             # Compatible with huggingface-hub>=0.26.0
# !pip install sentence-transformers==2.2.2  # Avoids higher version conflicts
# !pip install accelerate==0.20.3       # Compatible with huggingface-hub>=0.26.0
# !pip install diffusers==0.14.0        # Compatible with huggingface-hub>=0.26.0

# !pip install -q trimesh omegaconf einops rembg gradio
# !pip install -q https://github.com/camenduru/wheels/releases/download/colab/torchmcubes-0.1.0-cp310-cp310-linux_x86_64.whl

# !pip install onnxruntime

# !yes | pip uninstall gradio -q
# !pip install --upgrade gradio

# !pip install -q aiofiles fastapi pandas orjson typing-extensions huggingface-hub

# %cd /content/TripoSR-hf
# !python app.py
# Out:
# /content
# Cloning into 'TripoSR-hf'...
# remote: Enumerating objects: 102, done.
# remote: Counting objects: 100% (102/102), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 102 (delta 34), reused 95 (delta 30), pack-reused 0 (from 0)
# Receiving objects: 100% (102/102), 444.55 KiB | 1.67 MiB/s, done.
# Resolving deltas: 100% (34/34), done.
# /content/TripoSR-hf
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 5.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 709.3/709.3 kB 22.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 MB 17.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.6/322.6 kB 19.2 MB/s eta 0:00:00
# ...
